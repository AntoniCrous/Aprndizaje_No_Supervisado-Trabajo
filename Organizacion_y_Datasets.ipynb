# %% [markdown]
# <a href="https://colab.research.google.com/github/AntoniCrous/Aprndizaje_No_Supervisado-Trabajo/blob/master/Organizacion_y_Datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import itertools as it
import matplotlib.pyplot as plt
from matplotlib.cm import get_cmap
from scipy.cluster.hierarchy import dendrogram

# %%
np.random.seed(17) # Fijamos una semilla para asegurar la reproducibilidad de la práctica

data_file_url = 'https://raw.githubusercontent.com/jhernandezgonzalez/unsupervisedlearning/master/datasets/sipu/G2/g2-2-50.csv'
#'https://raw.githubusercontent.com/jhernandezgonzalez/unsupervisedlearning/master/datasets/sinteticos/dataset_cuatro_diferente_medida.csv'
#'https://raw.githubusercontent.com/jhernandezgonzalez/unsupervisedlearning/master/datasets/sinteticos/dataset_inseparable.csv'
#'https://raw.githubusercontent.com/jhernandezgonzalez/unsupervisedlearning/master/datasets/sipu/G2/g2-2-50.csv'
#'https://raw.githubusercontent.com/jhernandezgonzalez/unsupervisedlearning/master/datasets/sipu/G2/g2-2-10.csv'
Dx = np.array(pd.read_csv(data_file_url,header=None))
plt.scatter(Dx[:,0], Dx[:,1])
plt.show()

# %% [markdown]
# ### Organización de tareas para cada agrupamiento
# 1. Seleccionar Datasets <br>
# 2. Preparar algoritmos <br>
# 2.1. Algoritmo <br>
# 2.2. Validacion <br>
# 2.3. Parametrización<br>
# 2.4. Representacion Grafica<br>
# 3. Readacar Informe<br>

# %% [markdown]
# ### 5 Agrupamientos:
# - Por particiones: Kmeans
# - Jerárquico
# - Espectral
# - Por densidad
# - Modelos probabilisticos
